# %% [markdown]
# <a href="https://colab.research.google.com/github/2203A51181/srisrimanchena/blob/main/SCT_WD_TASK_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = '''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>SkillCraft Landing Page</title>
  <style>
    * { margin: 0; padding: 0; box-sizing: border-box; }

    body {
      font-family: 'Segoe UI', sans-serif;
      line-height: 1.6;
    }

    header {
      position: fixed;
      top: 0;
      width: 100%;
      background: transparent;
      padding: 15px 30px;
      transition: background 0.3s ease;
      z-index: 1000;
    }

    header.scrolled {
      background: #0e0e0e;
      color: #fff;
    }

    nav {
      display: flex;
      justify-content: space-between;
      align-items: center;
    }

    nav ul {
      display: flex;
      list-style: none;
      gap: 25px;
    }

    nav ul li a {
      text-decoration: none;
      color: #333;
      font-weight: 500;
      transition: color 0.3s ease;
    }

    nav ul li a:hover {
      color: #007BFF;
    }

    section {
      padding: 120px 30px;
      min-height: 100vh;
    }

    @media (max-width: 768px) {
      nav ul {
        flex-direction: column;
        background: #f1f1f1;
        position: absolute;
        top: 60px;
        right: 0;
        padding: 20px;
        display: none;
      }
      nav ul.show {
        display: flex;
      }
    }
  </style>
</head>
<body>

<header id="navbar">
  <nav>
    <div class="logo">SkillCraft</div>
    <ul>
      <li><a href="#home">Home</a></li>
      <li><a href="#about">About</a></li>
      <li><a href="#projects">Projects</a></li>
      <li><a href="#contact">Contact</a></li>
    </ul>
  </nav>
</header>

<section id="home">
  <h1>Welcome to SkillCraft Landing Page</h1>
</section>
<section id="about">
  <h2>About Us</h2>
</section>
<section id="projects">
  <h2>Projects</h2>
</section>
<section id="contact">
  <h2>Contact</h2>
</section>

<script>
  const navbar = document.getElementById('navbar');
  window.addEventListener('scroll', () => {
    navbar.classList.toggle('scrolled', window.scrollY > 50);
  });
</script>

</body>
</html>
'''

# Display HTML in an iframe in Colab
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>SkillCraft Landing Page</title>
#   <style>
#     * { margin: 0; padding: 0; box-sizing: border-box; }
#
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       line-height: 1.6;
#     }
#
#     header {
#       position: fixed;
#       top: 0;
#       width: 100%;
#       background: transparent;
#       padding: 15px 30px;
#       transition: background 0.3s ease;
#       z-index: 1000;
#     }
#
#     header.scrolled {
#       background: #0e0e0e;
#       color: #fff;
#     }
#
#     nav {
#       display: flex;
#       justify-content: space-between;
#       align-items: center;
#     }
#
#     nav ul {
#       display: flex;
#       list-style: none;
#       gap: 25px;
#     }
#
#     nav ul li a {
#       text-decoration: none;
#       color: #333;
#       font-weight: 500;
#       transition: color 0.3s ease;
# ...
